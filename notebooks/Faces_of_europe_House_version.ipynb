# %% [markdown]
# # Install libs

# %%
# !pip install geopandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting geopandas
#   Downloading geopandas-0.13.2-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 29.3 MB/s eta 0:00:00
# Collecting fiona>=1.8.19 (from geopandas)
#   Downloading Fiona-1.9.4.post1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 55.5 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from geopandas) (23.1)
# Requirement already satisfied: pandas>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from geopandas) (1.5.3)
# Collecting pyproj>=3.0.1 (from geopandas)
#   Downloading pyproj-3.6.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 66.7 MB/s eta 0:00:00
# Requirement already satisfied: shapely>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from geopandas) (2.0.1)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (23.1.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (2022.12.7)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (8.1.3)
# Collecting click-plugins>=1.0 (from fiona>=1.8.19->geopandas)
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Collecting cligj>=0.5 (from fiona>=1.8.19->geopandas)
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (1.22.4)
# Installing collected packages: pyproj, cligj, click-plugins, fiona, geopandas
# Successfully installed click-plugins-1.1.1 cligj-0.7.2 fiona-1.9.4.post1 geopandas-0.13.2 pyproj-3.6.0

# %% [markdown]
# backup original pictures before accessing

# %%
# !cp -r "/content/drive/MyDrive/AI/deliberate_model/europe_face_pictures" "/content/drive/MyDrive/AI/deliberate_model/europe_face_pictures_backup"

# %% [markdown]
# # Create mapping between country names and filenames

# %% [markdown]
# ### Nationality to country name map

# %%
european_countries = {
    'Albanian': 'Albania',
    'Andorran': 'Andorra',
    'Armenian': 'Armenia',
    'Austrian': 'Austria',
    'Azerbaijani': 'Azerbaijan',
    'Belarusian': 'Belarus',
    'Belgian': 'Belgium',
    'Bosnian': 'Bosnia and Herzegovina',
    'Bulgarian': 'Bulgaria',
    'Croatian': 'Croatia',
    'Cypriot': 'Cyprus',
    'Czech': 'Czech Republic',
    'Danish': 'Denmark',
    'Estonian': 'Estonia',
    'Finnish': 'Finland',
    'French': 'France',
    'Georgian': 'Georgia',
    'German': 'Germany',
    'Greek': 'Greece',
    'Hungarian': 'Hungary',
    'Icelandic': 'Iceland',
    'Irish': 'Ireland',
    'Italian': 'Italy',
    'Kazakhstani': 'Kazakhstan',
    'Kosovan': 'Kosovo',
    'Latvian': 'Latvia',
    'Liechtensteiner': 'Liechtenstein',
    'Lithuanian': 'Lithuania',
    'Luxembourger': 'Luxembourg',
    'Macedonian': 'North Macedonia',
    'Maltese': 'Malta',
    'Moldovan': 'Moldova',
    'Monégasque': 'Monaco',
    'Montenegrin': 'Montenegro',
    'Dutch': 'Netherlands',
    'Norwegian': 'Norway',
    'Polish': 'Poland',
    'Portuguese': 'Portugal',
    'Romanian': 'Romania',
    'Russian': 'Russia',
    'San Marinese': 'San Marino',
    'Serbian': 'Serbia',
    'Slovak': 'Slovakia',
    'Slovenian': 'Slovenia',
    'Spanish': 'Spain',
    'Swedish': 'Sweden',
    'Swiss': 'Switzerland',
    'Ukrainian': 'Ukraine',
    'British': 'United Kingdom',
    'Vatican': 'Vatican City'
}

# %% [markdown]
# ### Map country names to filenames

# %%
import os
import re
import pandas as pd

def find_country_name(filename):
  words = filename.split('-')
  for word in words:
    if word.capitalize() in european_countries:
      return european_countries[word.capitalize()]
  return None


def map_images_to_countries(directory):
    # Get list of image files in directory
    files = os.listdir(directory)
    country_to_image = []
    batch_count = 2
    for index, file in enumerate(files):
        # Look for nationality in the filename string using regex
        country_name = find_country_name(file)
        country_to_image.append([country_name,index % batch_count, os.path.join(directory, file)])
    return country_to_image


directory = "/content/drive/MyDrive/AI/deliberate_model/eu_national_architectural_prompts/"

country_to_filename_df = pd.DataFrame(map_images_to_countries(directory), columns = ["countryName", "batch_index", "filename"])
country_to_filename_df
# Out:
#        countryName  batch_index  \
# 0          Austria            0
# 1          Austria            1
# 2          Belgium            0
# 3          Belgium            1
# 4         Bulgaria            0
# 5         Bulgaria            1
# 6          Croatia            0
# 7          Croatia            1
# 8           Cyprus            0
# 9           Cyprus            1
# 10  Czech Republic            0
# 11  Czech Republic            1
# 12         Denmark            0
# 13         Denmark            1
# 14         Estonia            0
# 15         Estonia            1
# 16         Finland            0
# 17         Finland            1
# 18          France            0
# 19          France            1
# 20         Germany            0
# 21         Germany            1
# 22          Greece            0
# 23          Greece            1
# 24         Hungary            0
# 25         Hungary            1
# 26         Ireland            0
# 27         Ireland            1
# 28           Italy            0
# 29           Italy            1
# 30          Latvia            0
# 31          Latvia            1
# 32       Lithuania            0
# 33       Lithuania            1
# 34            None            0
# 35            None            1
# 36           Malta            0
# 37           Malta            1
# 38     Netherlands            0
# 39     Netherlands            1
# 40          Poland            0
# 41          Poland            1
# 42        Portugal            0
# 43        Portugal            1
# 44         Romania            0
# 45         Romania            1
# 46        Slovakia            0
# 47        Slovakia            1
# 48        Slovenia            0
# 49        Slovenia            1
# 50           Spain            0
# 51           Spain            1
# 52          Sweden            0
# 53          Sweden            1
#
#                                              filename
# 0   /content/drive/MyDrive/AI/deliberate_model/eu_...
# 1   /content/drive/MyDrive/AI/deliberate_model/eu_...
# 2   /content/drive/MyDrive/AI/deliberate_model/eu_...
# 3   /content/drive/MyDrive/AI/deliberate_model/eu_...
# 4   /content/drive/MyDrive/AI/deliberate_model/eu_...
# 5   /content/drive/MyDrive/AI/deliberate_model/eu_...
# 6   /content/drive/MyDrive/AI/deliberate_model/eu_...
# 7   /content/drive/MyDrive/AI/deliberate_model/eu_...
# 8   /content/drive/MyDrive/AI/deliberate_model/eu_...
# 9   /content/drive/MyDrive/AI/deliberate_model/eu_...
# 10  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 11  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 12  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 13  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 14  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 15  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 16  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 17  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 18  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 19  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 20  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 21  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 22  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 23  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 24  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 25  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 26  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 27  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 28  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 29  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 30  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 31  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 32  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 33  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 34  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 35  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 36  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 37  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 38  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 39  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 40  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 41  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 42  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 43  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 44  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 45  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 46  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 47  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 48  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 49  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 50  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 51  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 52  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 53  /content/drive/MyDrive/AI/deliberate_model/eu_...

# %%
country_to_filename_df
# Out:
#        countryName  batch_index  \
# 0          Austria            0
# 1          Austria            1
# 2          Belgium            0
# 3          Belgium            1
# 4         Bulgaria            0
# 5         Bulgaria            1
# 6          Croatia            0
# 7          Croatia            1
# 8           Cyprus            0
# 9           Cyprus            1
# 10  Czech Republic            0
# 11  Czech Republic            1
# 12         Denmark            0
# 13         Denmark            1
# 14         Estonia            0
# 15         Estonia            1
# 16         Finland            0
# 17         Finland            1
# 18          France            0
# 19          France            1
# 20         Germany            0
# 21         Germany            1
# 22          Greece            0
# 23          Greece            1
# 24         Hungary            0
# 25         Hungary            1
# 26         Ireland            0
# 27         Ireland            1
# 28           Italy            0
# 29           Italy            1
# 30          Latvia            0
# 31          Latvia            1
# 32       Lithuania            0
# 33       Lithuania            1
# 34            None            0
# 35            None            1
# 36           Malta            0
# 37           Malta            1
# 38     Netherlands            0
# 39     Netherlands            1
# 40          Poland            0
# 41          Poland            1
# 42        Portugal            0
# 43        Portugal            1
# 44         Romania            0
# 45         Romania            1
# 46        Slovakia            0
# 47        Slovakia            1
# 48        Slovenia            0
# 49        Slovenia            1
# 50           Spain            0
# 51           Spain            1
# 52          Sweden            0
# 53          Sweden            1
#
#                                              filename
# 0   /content/drive/MyDrive/AI/deliberate_model/eu_...
# 1   /content/drive/MyDrive/AI/deliberate_model/eu_...
# 2   /content/drive/MyDrive/AI/deliberate_model/eu_...
# 3   /content/drive/MyDrive/AI/deliberate_model/eu_...
# 4   /content/drive/MyDrive/AI/deliberate_model/eu_...
# 5   /content/drive/MyDrive/AI/deliberate_model/eu_...
# 6   /content/drive/MyDrive/AI/deliberate_model/eu_...
# 7   /content/drive/MyDrive/AI/deliberate_model/eu_...
# 8   /content/drive/MyDrive/AI/deliberate_model/eu_...
# 9   /content/drive/MyDrive/AI/deliberate_model/eu_...
# 10  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 11  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 12  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 13  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 14  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 15  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 16  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 17  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 18  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 19  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 20  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 21  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 22  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 23  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 24  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 25  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 26  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 27  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 28  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 29  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 30  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 31  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 32  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 33  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 34  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 35  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 36  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 37  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 38  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 39  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 40  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 41  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 42  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 43  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 44  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 45  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 46  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 47  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 48  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 49  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 50  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 51  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 52  /content/drive/MyDrive/AI/deliberate_model/eu_...
# 53  /content/drive/MyDrive/AI/deliberate_model/eu_...

# %% [markdown]
# ### Change image index in country name to filename map

# %%
def change_image_country_to_filename_map(country_to_filename_df, img_index, sex="woman"):

  # if sex == "woman":
  #   temp_df = country_to_filename_df[country_to_filename_df.filename.str.contains('woman')]
  # else:
  #   temp_df = country_to_filename_df[~country_to_filename_df.filename.str.contains('woman')]

  temp_df = country_to_filename_df[country_to_filename_df.batch_index == img_index][['countryName', 'filename']]
  temp_df.set_index('countryName', inplace=True)
  return temp_df.to_dict()['filename']

# %%
change_image_country_to_filename_map(country_to_filename_df, 1)
# Out:
# {'Austria': '/content/drive/MyDrive/AI/deliberate_model/eu_national_architectural_prompts/1686150532.6565785_42_Austrian_a-modern-interpretation-of-a-viennese-townhouse-designed-by-austrian-architect-hans-hollein_1.png',
#  'Belgium': '/content/drive/MyDrive/AI/deliberate_model/eu_national_architectural_prompts/1686150572.3879666_42_Belgian_a-perfect-blend-of-traditional-and-modern-architecture-in-a-belgian-townhouse-designed-by-belgian-ar_1.png',
#  'Bulgaria': '/content/drive/MyDrive/AI/deliberate_model/eu_national_architectural_prompts/1686150611.6233666_42_Bulgarian_a-modern-house-that-incorporates-traditional-bulgarian-elements-designed-by-bulgarian-architect-geor_1.png',
#  'Croatia': '/content/drive/MyDrive/AI/deliberate_model/eu_national_architectural_prompts/1686150650.7806408_42_Croatian_a-coastal-villa-that-blends-seamlessly-with-the-dalmatian-landscape-designed-by-croatian-architect-n_1.png',
#  'Cyprus': '/content/drive/MyDrive/AI/deliberate_model/eu_national_architectural_prompts/1686150689.989936_42_Cypriot_a-modern-villa-that-incorporates-traditional-cypriot-elements-designed-by-cypriot-architect-neoptole_1.png',
#  'Czech Republic': '/content/drive/MyDrive/AI/deliberate_model/eu_national_architectural_prompts/1686150729.2146928_42_Czech_a-perfect-blend-of-traditional-and-modern-architecture-in-a-czech-family-house-designed-by-czech-arc_1.png',
#  'Denmark': '/content/drive/MyDrive/AI/deliberate_model/eu_national_architectural_prompts/1686150768.4403894_42_Danish_a-modern-interpretation-of-a-danish-country-house-designed-by-danish-architect-jorn-utzon_1.png',
#  'Estonia': '/content/drive/MyDrive/AI/deliberate_model/eu_national_architectural_prompts/1686150807.9377759_42_Estonian_a-perfect-blend-of-traditional-and-modern-architecture-in-an-estonian-family-house-designed-by-eston_1.png',
#  'Finland': '/content/drive/MyDrive/AI/deliberate_model/eu_national_architectural_prompts/1686150847.3655674_42_Finnish_a-modern-interpretation-of-a-finnish-wooden-house-designed-by-finnish-architect-alvar-aalto_1.png',
#  'France': '/content/drive/MyDrive/AI/deliberate_model/eu_national_architectural_prompts/1686150886.9123716_42_French_a-perfect-blend-of-traditional-and-modern-architecture-in-a-french-country-house-designed-by-french-_1.png',
#  'Germany': '/content/drive/MyDrive/AI/deliberate_model/eu_national_architectural_prompts/1686150926.4263425_42_German_a-modern-interpretation-of-a-german-townhouse-designed-by-german-architect-walter-gropius_1.png',
#  'Greece': '/content/drive/MyDrive/AI/deliberate_model/eu_national_architectural_prompts/1686150965.963921_42_Greek_a-perfect-blend-of-traditional-and-modern-architecture-in-a-greek-island-villa-designed-by-greek-arc_1.png',
#  'Hungary': '/content/drive/MyDrive/AI/deliberate_model/eu_national_architectural_prompts/1686151005.239265_42_Hungarian_a-modern-interpretation-of-a-hungarian-country-house-designed-by-hungarian-architect-imre-makovecz_1.png',
#  'Ireland': '/content/drive/MyDrive/AI/deliberate_model/eu_national_architectural_prompts/1686151044.5020528_42_Irish_a-perfect-blend-of-traditional-and-modern-architecture-in-an-irish-family-house-designed-by-irish-ar_1.png',
#  'Italy': '/content/drive/MyDrive/AI/deliberate_model/eu_national_architectural_prompts/1686151084.0721786_42_Italian_a-modern-interpretation-of-an-italian-villa-designed-by-italian-architect-renzo-piano_1.png',
#  'Latvia': '/content/drive/MyDrive/AI/deliberate_model/eu_national_architectural_prompts/1686151123.2092032_42_Latvian_a-perfect-blend-of-traditional-and-modern-architecture-in-a-latvian-family-house-designed-by-latvian_1.png',
#  'Lithuania': '/content/drive/MyDrive/AI/deliberate_model/eu_national_architectural_prompts/1686151162.9032717_42_Lithuanian_a-modern-interpretation-of-a-lithuanian-wooden-house-designed-by-lithuanian-architect-raimundas-pusk_1.png',
#  None: '/content/drive/MyDrive/AI/deliberate_model/eu_national_architectural_prompts/1686151202.137323_42_Luxembourgish_a-perfect-blend-of-traditional-and-modern-architecture-in-a-luxembourgish-family-house-designed-by-l_1.png',
#  'Malta': '/content/drive/MyDrive/AI/deliberate_model/eu_national_architectural_prompts/1686151241.912192_42_Maltese_a-modern-interpretation-of-a-maltese-townhouse-designed-by-maltese-architect-richard-england_1.png',
#  'Netherlands': '/content/drive/MyDrive/AI/deliberate_model/eu_national_architectural_prompts/1686151281.1618328_42_Dutch_a-perfect-blend-of-traditional-and-modern-architecture-in-a-dutch-canal-house-designed-by-dutch-arch_1.png',
#  'Poland': '/content/drive/MyDrive/AI/deliberate_model/eu_national_architectural_prompts/1686151320.8151693_42_Polish_a-modern-interpretation-of-a-polish-country-house-designed-by-polish-architect-daniel-libeskind_1.png',
#  'Portugal': '/content/drive/MyDrive/AI/deliberate_model/eu_national_architectural_prompts/1686151360.1039238_42_Portuguese_a-perfect-blend-of-traditional-and-modern-architecture-in-a-portuguese-family-house-designed-by-port_1.png',
#  'Romania': '/content/drive/MyDrive/AI/deliberate_model/eu_national_architectural_prompts/1686151399.4129527_42_Romanian_a-modern-interpretation-of-a-romanian-wooden-house-designed-by-romanian-architect-serban-cantacuzino_1.png',
#  'Slovakia': '/content/drive/MyDrive/AI/deliberate_model/eu_national_architectural_prompts/1686151439.0222173_42_Slovak_a-perfect-blend-of-traditional-and-modern-architecture-in-a-slovak-family-house-designed-by-slovak-a_1.png',
#  'Slovenia': '/content/drive/MyDrive/AI/deliberate_model/eu_national_architectural_prompts/1686151478.70118_42_Slovenian_a-modern-interpretation-of-a-slovenian-alpine-house-designed-by-slovenian-architect-joze-plecnik_1.png',
#  'Spain': '/content/drive/MyDrive/AI/deliberate_model/eu_national_architectural_prompts/1686151518.2085977_42_Spanish_a-perfect-blend-of-traditional-and-modern-architecture-in-a-spanish-villa-designed-by-spanish-archit_1.png',
#  'Sweden': '/content/drive/MyDrive/AI/deliberate_model/eu_national_architectural_prompts/1686151557.560586_42_Swedish_a-modern-interpretation-of-a-swedish-wooden-house-designed-by-swedish-architect-greta-magnusson-gros_1.png'}

# %% [markdown]
# # Load euro map and define display function

# %% [markdown]
# ## load euro map

# %%
import geopandas as gpd

# Load world map
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Filter for Europe
europe = world[(world['continent'] == 'Europe')]
# Out:
# <ipython-input-12-5be0df5da824>:4: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
europe.head()
# Out:
#          pop_est continent     name iso_a3  gdp_md_est  \
# 18   144373535.0    Europe   Russia    RUS     1699876
# 21     5347896.0    Europe   Norway    NOR      403336
# 43    67059887.0    Europe   France    FRA     2715518
# 110   10285453.0    Europe   Sweden    SWE      530883
# 111    9466856.0    Europe  Belarus    BLR       63080
#
#                                               geometry
# 18   MULTIPOLYGON (((180.00000 71.51571, 180.00000 ...
# 21   MULTIPOLYGON (((15.14282 79.67431, 15.52255 80...
# 43   MULTIPOLYGON (((-51.65780 4.15623, -52.24934 3...
# 110  POLYGON ((11.02737 58.85615, 11.46827 59.43239...
# 111  POLYGON ((28.17671 56.16913, 29.22951 55.91834...

# %% [markdown]
# ## define display function

# %%
import folium
import geopandas as gpd
from PIL import Image
import base64
from io import BytesIO


def display_euro_map_for_image_dict(image_dict):

  img_zoom = 1
  img_width = 90 * img_zoom
  img_height = 90 * img_zoom

  # Load world map
  world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

  # Filter for Europe
  europe = world[world['continent'] == 'Europe']

  # Create map centered around Europe
  euro_map = folium.Map(location=[54.5260, 15.2551], zoom_start=4)

  # Add a marker for each country
  for country in europe.itertuples():
      country_name = country.name
      if country_name in image_dict:
          # Open image, resize and convert to base64
          img = Image.open(image_dict[country_name])
          img = img.resize((img_width, img_height))
          buffered = BytesIO()
          img.save(buffered, format="PNG")
          img_str = base64.b64encode(buffered.getvalue()).decode()

          # Creating icon with image and country name
          html = '<div style="text-align: center;"><b>{}</b><br><img src="data:image/png;base64,{}" style="border-radius: 8px;"></div>'.format(country_name, img_str)

          icon = folium.DivIcon(
              icon_size=(img_width, img_height),
              icon_anchor=(30, 45),
              html=html,
          )

          # Add marker to map with image icon
          folium.Marker(
              location=[country.geometry.representative_point().y, country.geometry.representative_point().x],
              icon=icon,
          ).add_to(euro_map)

  # Display map
  return euro_map

# %% [markdown]
# ### example usage

# %%
image_dict = change_image_country_to_filename_map(country_to_filename_df, 1)
display_euro_map_for_image_dict(image_dict)
# Out:
# <ipython-input-18-02b0393a300a>:15: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b5c778a6f54bfaf03afbcc943668ba8c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b5c778a6f54bfaf03afbcc943668ba8c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b5c778a6f54bfaf03afbcc943668ba8c = L.map(
#                 &quot;map_b5c778a6f54bfaf03afbcc943668ba8c&quot;,
#                 {
#                     center: [54.526, 15.2551],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_86021901d4f1787547b681bcf5a0a851 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b5c778a6f54bfaf03afbcc943668ba8c);
#
#
#             var marker_d01b93662350cfd7fc95fcac89b5c7b2 = L.marker(
#                 [46.895070705750044, 2.099228142939435],
#                 {}
#             ).addTo(map_b5c778a6f54bfaf03afbcc943668ba8c);
#
#
#             var div_icon_90d167ea9048ce5760a6a888222b1b65 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;text-align: center;\&quot;\u003e\u003cb\u003eFrance\u003c/b\u003e\u003cbr\u003e\u003cimg src=\&quot;data:image/png;base64,...\&quot; style=\&quot;border-radius: 8px;\&quot;\u003e\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [30, 45], &quot;iconSize&quot;: [90, 90]});
#             marker_d01b93662350cfd7fc95fcac89b5c7b2.setIcon(div_icon_90d167ea9048ce5760a6a888222b1b65);
#
#
#             var marker_161bec0a9b531a5fcefff175620fa727 = L.marker(
#                 [62.27488129337668, 14.786243427055595],
#                 {}
#             ).addTo(map_b5c778a6f54bfaf03afbcc943668ba8c);
#
#
#             var div_icon_1c1b6cb45208f5237e23ed9232c1d690 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;text-align: center;\&quot;\u003e\u003cb\u003eSweden\u003c/b\u003e\u003cbr\u003e\u003cimg src=\&quot;data:image/png;base64,...\&quot; style=\&quot;border-radius: 8px;\&quot;\u003e\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [30, 45], &quot;iconSize&quot;: [90, 90]});
#             marker_161bec0a9b531a5fcefff175620fa727.setIcon(div_icon_1c1b6cb45208f5237e23ed9232c1d690);
#
#
#             var marker_548f3bddf988a1a517949fec3ae11c77 = L.marker(
#                 [51.88441732442235, 19.076267455907114],
#                 {}
#             ).addTo(map_b5c778a6f54bfaf03afbcc943668ba8c);
#
#
#             var div_icon_a76ba94d71f410c1e50b0a5df7dcb86f = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;text-align: center;\&quot;\u003e\u003cb\u003ePoland\u003c/b\u003e\u003cbr\u003e\u003cimg src=\&quot;data:image/png;base64,...\&quot; style=\&quot;border-radius: 8px;\&quot;\u003e\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [30, 45], &quot;iconSize&quot;: [90, 90]});
#             marker_548f3bddf988a1a517949fec3ae11c77.setIcon(div_icon_a76ba94d71f410c1e50b0a5df7dcb86f);
#
#
#             var marker_c46982a5d35c620b1543b490e5e9ccc7 = L.marker(
#                 [47.91918132180231, 14.953149823900707],
#                 {}
#             ).addTo(map_b5c778a6f54bfaf03afbcc943668ba8c);
#
#
#             var div_icon_a424272c7929a9c7bd3cfff9efa1b3dd = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;text-align: center;\&quot;\u003e\u003cb\u003eAustria\u003c/b\u003e\u003cbr\u003e\u003cimg src=\&quot;data:image/png;base64,...\&quot; style=\&quot;border-radius: 8px;\&quot;\u003e\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [30, 45], &quot;iconSize&quot;: [90, 90]});
#             marker_c46982a5d35c620b1543b490e5e9ccc7.setIcon(div_icon_a424272c7929a9c7bd3cfff9efa1b3dd);
#
#
#             var marker_11ba6c94fab7cd0e416af1b034ebcdac = L.marker(
#                 [47.24520437274364, 19.103248422838412],
#                 {}
#             ).addTo(map_b5c778a6f54bfaf03afbcc943668ba8c);
#
#
#             var div_icon_8b63f1d110cb36b62f51a8c1d1422ba8 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;text-align: center;\&quot;\u003e\u003cb\u003eHungary\u003c/b\u003e\u003cbr\u003e\u003cimg src=\&quot;data:image/png;base64,...\&quot; style=\&quot;border-radius: 8px;\&quot;\u003e\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [30, 45], &quot;iconSize&quot;: [90, 90]});
#             marker_11ba6c94fab7cd0e416af1b034ebcdac.setIcon(div_icon_8b63f1d110cb36b62f51a8c1d1422ba8);
#
#
#             var marker_c20cdc2988a08c67b57b9c434293c053 = L.marker(
#                 [46.03602753354609, 24.2116924300108],
#                 {}
#             ).addTo(map_b5c778a6f54bfaf03afbcc943668ba8c);
#
#
#             var div_icon_bd5697ee9ee599f9254c004

# %% [markdown]
# # Export data to GeoJSON

# %%
import json
import base64
from PIL import Image
from io import BytesIO

def create_geojson(image_dict, geojson_export_name):
    img_zoom = 1
    img_width = 90 * img_zoom
    img_height = 90 * img_zoom

    # GeoJSON object
    geojson = {
        "type": "FeatureCollection",
        "features": []
    }

    # Load world map
    world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

    # Filter for Europe
    europe = world[world['continent'] == 'Europe']

    for country in europe.itertuples():
        country_name = country.name
        if country_name in image_dict:
            # Open image, resize and convert to base64
            img = Image.open(image_dict[country_name])
            img = img.resize((img_width, img_height))
            buffered = BytesIO()
            img.save(buffered, format="PNG")
            img_str = base64.b64encode(buffered.getvalue()).decode()

            # Create feature for each country with location and image
            feature = {
                "type": "Feature",
                "geometry": {
                    "type": "Point",
                    "coordinates": [
                        float(country.geometry.representative_point().x),
                        float(country.geometry.representative_point().y)
                    ]
                },
                "properties": {
                    "name": country_name,
                    "image": img_str
                }
            }
            geojson["features"].append(feature)

    # Write GeoJSON to file
    with open(f'{geojson_export_name}.geojson', 'w') as f:
        json.dump(geojson, f)

# %%
image_dict = change_image_country_to_filename_map(country_to_filename_df, 0)
create_geojson(image_dict, 'europe_architecture_batch_1')

image_dict = change_image_country_to_filename_map(country_to_filename_df, 1)
create_geojson(image_dict, 'europe_architecture_batch_2')
# Out:
# <ipython-input-20-6d3c379993e8>:18: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# <ipython-input-20-6d3c379993e8>:18: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
